# %% [markdown]
# # Application: Analysing Functions

# %%
import numpy as np
import matplotlib.pyplot as plt

# set values of constants

vx0 = 5     # initial x velocity
vy0 = 0
mu = .3   # 
g = 9.81    # acceleration due to gravity

# calculate y for integer values of t from 0 to 9

for tehta in range(0, np.pi/2, 0.2):
    t = np.linspace(0, 15, 100)
    x = (vx0/mu) * (1 - np.exp(-mu * t))
    y = -(g/mu)*t + (1/mu)*(vy0 + (g/mu))*(1 - np.exp(-mu * t))
    print("t (seconds):", t)
    print("x (metres):", x)
    print("y (metres):", y)

    plt.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24716\1649757896.py in <module>
#      11 # calculate y for integer values of t from 0 to 9
#      12
# ---> 13 for tehta in range(0, np.pi/2, 0.2):
#      14     t = np.linspace(0, 15, 100)
#      15     x = (vx0/mu) * (1 - np.exp(-mu * t))
#
# TypeError: 'float' object cannot be interpreted as an integer

# %% [markdown]
# ### Exercise
#
# 1. $$f(x) = \log\left(\frac{1+x}{1-x}\right)$$

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 5
b = 0.2
f = 2

t = np.linspace(0, 10, 100)
v = a * np.exp( - b * t) * np.cos(2 * np.pi * f * t)

plt.plot(t, v)

v
# Out:
# array([ 5.        ,  1.45491084, -3.95530038, -3.69914205,  1.64590696,
#         4.51052006,  1.04423059, -3.72420445, -3.17023461,  1.7317674 ,
#         4.05252436,  0.69523295, -3.48744896, -2.69727356,  1.77963357,
#         3.62614836,  0.40112659, -3.2491163 , -2.27611232,  1.79583939,
#         3.23109575,  0.15565597, -3.0125624 , -1.90269607,  1.78596765,
#         2.8667213 , -0.04691613, -2.78050643, -1.57309726,  1.75491554,
#         2.53210295, -0.2118296 , -2.55511228, -1.2835428 ,  1.70695707,
#         2.22610434, -0.3438505 , -2.33806227, -1.03043438,  1.64580203,
#         1.94742863, -0.44729643, -2.13062359, -0.81036286,  1.57465143,
#         1.69466453, -0.52606299, -1.93370795, -0.62011747,  1.49624942,
#         1.46632544, -0.58365081, -1.74792484, -0.45669091,  1.4129315 ,
#         1.2608823 , -0.62319275, -1.57362897, -0.3172808 ,  1.32666923,
#         1.07679108, -0.64748088, -1.41096235, -0.19928828,  1.23911143,
#         0.91251539, -0.65899285, -1.25989132, -0.10031421,  1.15162199,
#         0.76654483, -0.65991753, -1.12023913, -0.01815356,  1.06531442,
#         0.6374097 , -0.65217966, -0.99171442,  0.04921178,  0.98108334,
#         0.52369245, -0.6374634 , -0.87393589,  0.10362118,  0.89963301,
#         0.42403641, -0.61723466, -0.76645369,  0.14674427,  0.82150307,
#         0.33715209, -0.59276213, -0.66876774,  0.18009056,  0.7470917 ,
#         0.26182151, -0.56513708, -0.58034335,  0.20501926,  0.67667642])
